# %%
import csv
with open("battery.csv",encoding="utf-8") as file:
    csvREADER=csv.reader(file)
    print(type(csvREADER))
    for row in csvREADER:
        print(row)
# Out:
# <class '_csv.reader'>
# ['\ufeffsitename', 'address', '縣市代碼', '', 'city', 'dist']
# ['西歐台北士林加油站', '台北市士林區中山北路五段570號(近福林公園)', 'A', '台北市士林區', '台北市', '士林區']
# ['全聯士林中正店站', '台北市士林區中正路115號(近中正路/中山北路五段路口)', 'A', '台北市士林區', '台北市', '士林區']
# ['台北捷運士林站', '台北市士林區中正路247巷捷運站2號出口(近捷運站機車轉乘停車場)', 'A', '台北市士林區', '台北市', '士林區']
# ['文昌國小地下停車場B1F站', '台北市士林區文林路615巷20號(地下一樓機車停車場)(近文林路615巷6弄巷口)', 'A', '台北市士林區', '台北市', '士林區']
# ['Gogoro 士林文林店站', '台北市士林區文林路65號(近士林夜市)', 'A', '台北市士林區', '台北市', '士林區']
# ['故宮廣場停車場站', '台北市士林區至善路二段134號(近至善路二段/力行街口)', 'A', '台北市士林區', '台北市', '士林區']
# ['社子國小地下停車場B1F站', '台北市士林區延平北路6段308號(地下一樓機車停車場)(近社中街450號)', 'A', '台北市士林區', '台北市', '士林區']
# ['延平北路5段臨時平面停車場站', '台北市士林區延平北路五段1巷(近富光區民活動中心)', 'A', '台北市士林區', '台北市', '士林區']
# ['Gogoro 天母忠誠門市站', '台北市士林區忠誠路一段101號(近雨農國小)', 'A', '台北市士林區', '台北市', '士林區']
# ['天母大葉高島屋百貨公司站', '台北市士林區忠誠路二段55號(近大葉天母私有停車場入口)', 'A', '台北市士林區', '台北市', '士林區']
# ['Gogoro 士林承德服務中心站', '台北市士林區承德路四段340號(近承德路四段/福港街口)', 'A', '台北市士林區', '台北市', '士林區']
# ...
